# %% [markdown]
# # 데이터 준비
#  - 데이콘: [코로나 데이터 시각화 AI 경진대회](https://dacon.io/competitions/official/235590/overview/description)
#  - 참고자료: [코로나19와의 전쟁에서 생명 구하기 - '사망'에 대한 insights 도출](https://dacon.io/competitions/official/235590/codeshare/949?page=1&dtype=vote)

# %% [markdown]
# 데이터 목록
# 1. Case.csv:
#    - case_id, province, city, group, infection_case, confirmed, latitude, longitude
# 1. PatientInfo.csv
#    - patient_id, global_num, date, province, city, latitude, longitude
# 1. PatientRoute.csv
#    - patient_id, global_num, date,province, city, latitude, longitude
# 1. Time.csv
#    - date, time, test, negative, confirmed, released, deceased
# 1. TimeAge.csv
#    - date, time, age, confirmed, deceased
# 1. TimeGender.csv
#    - date, time, sex, confirmed, deceased
# 1. TimeProvince.csv
#    - date, time, province, confirmed, released, deceased
# 1. Region.csv
#    - code, province, city, latitude, longitude, elementary_school_count, kindergarten_count, university_count, academy_ratio, elderly_population_ratio, elderly_alone_ratio, nursing_home_count
# 1. Weather.csv
#    - code, province, date, avg_temp, min_temp, max_temp, precipitation, max_wind_speed, most_wind_direction, avg_relative_humidity
# 1. Searchtrend.csv
#    - date, cold, flu, pneumonia, coronavirus
# 1. SeoulFloating.csv
#    - date, hour, birth_year, sex, province, city, fp_num
# 1. Policy.csv
#    - policy_id, country, type, gov_policy, detail, start_date, end_date

# %%
from IPython.display import HTML
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.animation as animation

import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook_connected"

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler 
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

pd.set_option('display.float_format', lambda x: '%.2f' % x)
import warnings  
warnings.filterwarnings('ignore')

import os

# %%
os.listdir('./data')
# Out:
# ['Case.csv',
#  'coronavirusdataset_20200430.zip',
#  'PatientInfo.csv',
#  'PatientRoute.csv',
#  'Policy.csv',
#  'Region.csv',
#  'SearchTrend.csv',
#  'SeoulFloating.csv',
#  'Time.csv',
#  'TimeAge.csv',
#  'TimeGender.csv',
#  'TimeProvince.csv',
#  'Weather.csv']

# %% [markdown]
# - 참고자료: [변수 이름을 loop 돌려서 할당하기](https://blog.naver.com/nomadgee/220857820094)

# %%
tables = []
for name in os.listdir('./data'):
    if name.endswith('csv'):
        table = name.split('.')[0]
        globals()[table] = pd.read_csv(os.path.join('./data', name))
        tables.append(table)
print(tables)
# Out:
# ['Case', 'PatientInfo', 'PatientRoute', 'Policy', 'Region', 'SearchTrend', 'SeoulFloating', 'Time', 'TimeAge', 'TimeGender', 'TimeProvince', 'Weather']

# %%
# table = 'Case'
# exec("print(%s.head(3))"%(table))
for table in tables:
    print(f'##################{table}##########')
    print(globals()[table].head(3))
# Out:
# ##################Case##########
#    case_id province           city  group         infection_case  confirmed  \
# 0  1000001    Seoul        Guro-gu   True    Guro-gu Call Center         98
# 1  1000002    Seoul  Dongdaemun-gu   True          Dongan Church         20
# 2  1000003    Seoul        Guro-gu   True  Manmin Central Church         41
#
#     latitude   longitude
# 0  37.508163  126.884387
# 1  37.592888  127.056766
# 2  37.481059  126.894343
# ##################PatientInfo##########
#    patient_id  global_num   sex  birth_year  age country province  \
# 0  1000000001        2.00  male     1964.00  50s   Korea    Seoul
# 1  1000000002        5.00  male     1987.00  30s   Korea    Seoul
# 2  1000000003        6.00  male     1964.00  50s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow             1.00           nan
# 1  Jungnang-gu     NaN       overseas inflow             1.00           nan
# 2    Jongno-gu     NaN  contact with patient             2.00 2002000001.00
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# 0           75.00         2020-01-22     2020-01-23    2020-02-05
# 1           31.00                NaN     2020-01-30    2020-03-02
# 2           17.00                NaN     2020-01-30    2020-02-19
#
#   deceased_date     state
# 0           NaN  released
# 1           NaN  released
# 2           NaN  released
# ##################PatientRoute##########
#    patient_id  global_num        date     province         city      type  \
# 0  1000000001        2.00  2020-01-22  Gyeonggi-do     Gimpo-si   airport
# 1  1000000001        2.00  2020-01-24        Seoul      Jung-gu  hospital
# 2  1000000002        5.00  2020-01-25        Seoul  Seongbuk-gu       etc
#
#    latitude  longitude
# 0     37.62     126.72
# 1     37.57     127.01
# 2     37.59     127.02
# ##################Policy##########
#    policy_id country   type                      gov_policy            detail  \
# 0          1   Korea  Alert  Infectious Disease Alert Level    Level 1 (Blue)
# 1          2   Korea  Alert  Infectious Disease Alert Level  Level 2 (Yellow)
# 2          3   Korea  Alert  Infectious Disease Alert Level  Level 3 (Orange)
#
#    start_date    end_date
# 0  2020-01-03  2020-01-19
# 1  2020-01-20  2020-01-27
# 2  2020-01-28  2020-02-22
# ##################Region##########
#     code province         city  latitude  longitude  elementary_school_count  \
# 0  10000    Seoul        Seoul     37.57     126.98                      607
# 1  10010    Seoul   Gangnam-gu     37.52     127.05                       33
# 2  10020    Seoul  Gangdong-gu     37.53     127.12                       27
#
#    kindergarten_count  university_count  academy_ratio  \
# 0                 830                48           1.44
# 1                  38                 0           4.18
# 2                  32                 0           1.54
#
#    elderly_population_ratio  elderly_alone_ratio  nursing_home_count
# 0                     15.38                 5.80               22739
# 1                     13.17                 4.30                3088
# 2                     14.55                 5.40                1023
# ##################SearchTrend##########
#          date  cold  flu  pneumonia  coronavirus
# 0  2016-01-01  0.12 0.06       0.16         0.01
# 1  2016-01-02  0.13 0.17       0.21         0.01
# 2  2016-01-03  0.15 0.22       0.19         0.01
# ##################SeoulFloating##########
#          date  hour  birth_year     sex province           city  fp_num
# 0  2020-01-01     0          20  female    Seoul      Dobong-gu   19140
# 1  2020-01-01     0          20    male    Seoul      Dobong-gu   19950
# 2  2020-01-01     0          20  female    Seoul  Dongdaemun-gu   25450
# ##################Time##########
#          date  time  test  negative  confirmed  released  deceased
# 0  2020-01-20    16     1         0          1         0         0
# 1  2020-01-21    16     1         0          1         0         0
# 2  2020-01-22    16     4         3          1         0         0
# ##################TimeAge##########
#          date  time  age  confirmed  deceased
# 0  2020-03-02     0   0s         32         0
# 1  2020-03-02     0  10s        169         0
# 2  2020-03-02     0  20s       1235         0
# ##################TimeGender##########
#          date  time     sex  confirmed  deceased
# 0  2020-03-02     0    male       1591        13
# 1  2020-03-02     0  female       2621         9
# 2  2020-03-03     0    male       1810        16
# ##################TimeProvince##########
#          date  time province  confirmed  released  deceased
# 0  2020-01-20    16    Seoul          0         0         0
# 1  2020-01-20    16    Busan          0         0         0
# 2  2020-01-20    16    Daegu          0         0         0
# ##################Weather##########
#     code province        date  avg_temp  min_temp  max_temp  precipitation  \
# 0  10000    Seoul  2016-01-01      1.20     -3.30      4.00           0.00
# 1  11000    Busan  2016-01-01      5.30      1.10     10.90           0.00
# 2  12000    Daegu  2016-01-01      1.70     -4.00      8.00           0.00
#
#    max_wind_speed  most_wind_direction  avg_relative_humidity
# 0            3.50                90.00                  73.00
# 1            7.40               340.00                  52.10
# 2            3.70               270.00                  70.50

# %% [markdown]
# # EDA

# %% [markdown]
# ## 1.1. 감염 경로 유형

# %%
data = PatientInfo.copy()

# %%
print('the number of unique values in infection_case:',len(data['infection_case'].unique())) 
data['infection_case'].value_counts()
# Out:
# the number of unique values in infection_case: 24
# contact with patient                     968
# overseas inflow                          604
# etc                                      572
# Guro-gu Call Center                      112
# Shincheonji Church                       107
# Onchun Church                             33
# Bonghwa Pureun Nursing Home               31
# gym facility in Cheonan                   30
# Ministry of Oceans and Fisheries          28
# Cheongdo Daenam Hospital                  21
# Dongan Church                             17
# Eunpyeong St. Mary's Hospital             16
# Gyeongsan Seorin Nursing Home             15
# Seongdong-gu APT                          13
# Gyeongsan Jeil Silver Town                12
# Milal Shelter                             11
# Gyeongsan Cham Joeun Community Center     10
# Geochang Church                            6
# Changnyeong Coin Karaoke                   4
# gym facility in Sejong                     4
# Suyeong-gu Kindergarten                    3
# Pilgrimage to Israel                       2
# River of Grace Community Church            1
# Name: infection_case, dtype: int64

# %% [markdown]
# - 100명 정도로는 하나의 그룹이라 부르기 어렵다. 그렇다면 다 합쳐서 집단 감염이라고 해보자.
# - 그런데 6명도 집단 감염이라고 할 수 있나 ? 없애버리자.

# %%
g = data.groupby(['infection_case'])['patient_id'].count()
g = g.reset_index()
g.rename(columns = {'patient_id': 'count'}, inplace = True)

g = g.sort_values('count', ascending = False)

plt.figure(figsize = (12,6))
plt.title('number of patients in infection_case values')
sns.barplot(y = 'infection_case', x= 'count', data = g)
plt.show()

# %%
g = data.groupby(['infection_case'])['patient_id'].count()
g = pd.DataFrame(g)

infection_case_less_than_10 = g[g['patient_id'] < 10].index.tolist()
g[g.index.isin(infection_case_less_than_10)]
# Out:
#                                  patient_id
# infection_case
# Changnyeong Coin Karaoke                  4
# Geochang Church                           6
# Pilgrimage to Israel                      2
# River of Grace Community Church           1
# Suyeong-gu Kindergarten                   3
# gym facility in Sejong                    4

# %%
print('original data shape:', data.shape)
data = data[~(data['infection_case'].isin(infection_case_less_than_10))]
print('data shape after slicing: ', data.shape)
# Out:
# original data shape: (3388, 18)
# data shape after slicing:  (3368, 18)

# %% [markdown]
# - 결측값 처리

# %%
ratio = data['infection_case'].isnull().sum() / len(data['infection_case'])
print(f'{ratio*100:.2f}%를 차지함')
# Out:
# 22.80%를 차지함

# %%
def categorise(x):
    '''
    categorises infection types
    '''
    if x == 'overseas inflow':
        y = 'overseas'
    elif x == 'contact with patient': 
        y = 'individual'
    elif (x == 'etc') | (pd.isnull(x)):
        y = 'unknown'
    else: 
        y = 'group'
    return y 

data['infection'] = data['infection_case'].apply(lambda x: categorise(x))
print(data.shape)
data.head()
# Out:
# (3368, 19)
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001        2.00    male     1964.00  50s   Korea    Seoul
# 1  1000000002        5.00    male     1987.00  30s   Korea    Seoul
# 2  1000000003        6.00    male     1964.00  50s   Korea    Seoul
# 3  1000000004        7.00    male     1991.00  20s   Korea    Seoul
# 4  1000000005        9.00  female     1992.00  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow             1.00           nan
# 1  Jungnang-gu     NaN       overseas inflow             1.00           nan
# 2    Jongno-gu     NaN  contact with patient             2.00 2002000001.00
# 3      Mapo-gu     NaN       overseas inflow             1.00           nan
# 4  Seongbuk-gu     NaN  contact with patient             2.00 1000000002.00
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# 0           75.00         2020-01-22     2020-01-23    2020-02-05
# 1           31.00                NaN     2020-01-30    2020-03-02
# 2           17.00                NaN     2020-01-30    2020-02-19
# 3            9.00         2020-01-26     2020-01-30    2020-02-15
# 4            2.00                NaN     2020-01-31    2020-02-24
#
#   deceased_date     state   infection
# 0           NaN  released    overseas
# 1           NaN  released    overseas
# 2           NaN  released  individual
# 3           NaN  released    overseas
# 4           NaN  released  individual

# %%
g = data.groupby(['infection'])['patient_id'].count()
g = g.reset_index()
g.rename(columns = {'patient_id': 'count'}, inplace = True)

g = g.sort_values('count', ascending = False)

plt.figure(figsize = (12,6))
sns.barplot(y = 'infection', x= 'count', data = g)
plt.title('number of patients in infection values')
plt.show()

# %% [markdown]
# ## 1.2. 유동성

# %%
tables
# Out:
# ['Case',
#  'PatientInfo',
#  'PatientRoute',
#  'Policy',
#  'Region',
#  'SearchTrend',
#  'SeoulFloating',
#  'Time',
#  'TimeAge',
#  'TimeGender',
#  'TimeProvince',
#  'Weather']

# %%
data_route = PatientRoute.copy()

# %%
print('the number of unique values in type:', len(data_route['type'].unique()))
data_route['type'].value_counts()
# Out:
# the number of unique values in type: 24
# etc                            2049
# hospital                       1927
# store                           641
# restaurant                      528
# public_transportation           462
# airport                         237
# pharmacy                        230
# church                          148
# cafe                            102
# pc_cafe                          80
# school                           58
# lodging                          45
# bank                             32
# bakery                           26
# gym                              20
# beauty_salon                     19
# real_estate_agency               19
# post_office                      17
# administrative_area_level_1      14
# university                       14
# bar                              13
# gas_station                      12
# academy                          11
# karaoke                          10
# Name: type, dtype: int64

# %%
data_route['type'].isnull().sum()
# Out:
# 0

# %% [markdown]
# - 재그룹화: 필수적 이동이었는가 ? 부수적 이동이었는가 ?

# %%
## categories
leisure = ['library', 'theater', 'cafe', 'bakery', 'beauty_salon',
          'pc_cafe', 'billiards','restaurant', 'bar', 'karaoke']
travel = ['airport', 'lodging']
essential_edu = ['primary_school', 'school', 'university']
non_essential_edu = ['academy']
exercise = ['gym', 'mountain', 'park']
essential_admin = ['administrative_area_level_1', 'governmnet_office', 'post_office']
non_essential_admin = ['police_office', 'bank', 'real_estate_agency']
necessity = ['store', 'public_transportation', 'gas_station']
medical = ['hospital', 'pharmacy']
church = ['church']
etc = ['etc']

# %%
essential = essential_edu + essential_admin + necessity + medical 
def type_group_essen(x): 
    group = None
    if x in essential: 
        group = 'essential'
    else:
        group = 'non-essential' 
    return group

# %%
data_route['route_group_essential'] = data_route['type'].apply(lambda x: type_group_essen(x)) 
data_route = data_route[['patient_id', 'type', 'route_group_essential']]
data_route.head()
# Out:
#    patient_id                   type route_group_essential
# 0  1000000001                airport         non-essential
# 1  1000000001               hospital             essential
# 2  1000000002                    etc         non-essential
# 3  1000000002                  store             essential
# 4  1000000002  public_transportation             essential

# %% [markdown]
# - 참고자료: [R friend 데이터 재구조화](https://rfriend.tistory.com/276)

# %%
# g = pd.DataFrame(data_route.groupby(['patient_id', 'route_group_essential'])['patient_id'].count())
# g = g.unstack()

g = pd.DataFrame(data_route.groupby(['patient_id', 'route_group_essential'])['patient_id'].count().unstack())
g
# Out:
# route_group_essential  essential  non-essential
# patient_id
# 1000000001                  1.00           1.00
# 1000000002                  9.00           4.00
# 1000000003                   nan           2.00
# 1000000004                  1.00            nan
# 1000000005                  1.00            nan
# ...                          ...            ...
# 6100000086                  2.00           2.00
# 6100000087                  6.00           2.00
# 6100000088                  5.00          19.00
# 6100000089                  1.00           1.00
# 6100000090                  3.00           4.00
#
# [1211 rows x 2 columns]

# %% [markdown]
# - 여기서 nan은 이동하지 않았다는 뜻!

# %%
g.fillna(0, inplace = True)
g.reset_index(inplace = True)
g = g[['patient_id', 'essential', 'non-essential']]
g.head()
# Out:
# route_group_essential  patient_id  essential  non-essential
# 0                      1000000001       1.00           1.00
# 1                      1000000002       9.00           4.00
# 2                      1000000003       0.00           2.00
# 3                      1000000004       1.00           0.00
# 4                      1000000005       1.00           0.00

# %%
# data = data.merge(g, left_on = 'patient_id', right_on = 'patient_id', how = 'left')
data = pd.merge(data, g, on = 'patient_id', how = 'left')
data.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001        2.00    male     1964.00  50s   Korea    Seoul
# 1  1000000002        5.00    male     1987.00  30s   Korea    Seoul
# 2  1000000003        6.00    male     1964.00  50s   Korea    Seoul
# 3  1000000004        7.00    male     1991.00  20s   Korea    Seoul
# 4  1000000005        9.00  female     1992.00  20s   Korea    Seoul
#
#           city disease        infection_case  ...   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow  ...           nan
# 1  Jungnang-gu     NaN       overseas inflow  ...           nan
# 2    Jongno-gu     NaN  contact with patient  ... 2002000001.00
# 3      Mapo-gu     NaN       overseas inflow  ...           nan
# 4  Seongbuk-gu     NaN  contact with patient  ... 1000000002.00
#
#    contact_number  symptom_onset_date confirmed_date released_date  \
# 0           75.00          2020-01-22     2020-01-23    2020-02-05
# 1           31.00                 NaN     2020-01-30    2020-03-02
# 2           17.00                 NaN     2020-01-30    2020-02-19
# 3            9.00          2020-01-26     2020-01-30    2020-02-15
# 4            2.00                 NaN     2020-01-31    2020-02-24
#
#   deceased_date     state   infection essential  non-essential
# 0           NaN  released    overseas      1.00           1.00
# 1           NaN  released    overseas      9.00           4.00
# 2           NaN  released  individual      0.00           2.00
# 3           NaN  released    overseas      1.00           0.00
# 4           NaN  released  individual      1.00           0.00
#
# [5 rows x 21 columns]

# %%
print(data.shape)
data[(data['essential'].isnull()) | (data['non-essential'].isnull())].shape
# Out:
# (3368, 21)
# (2169, 21)

# %% [markdown]
# - data에 포함된 id 중에는 data_route에서 측정되지 않은 데이터가 2000명이나 있었어
# - 일단 포함된 1000명만 생각해보자

# %%
print('original data shape:', data.shape)
data_with_route = data[(data['essential'].notnull()) & (data['non-essential'].notnull())] 
print('data shape after removing missing values in essentail/non-essential:', data_with_route.shape)
# Out:
# original data shape: (3368, 21)
# data shape after removing missing values in essentail/non-essential: (1199, 21)

# %% [markdown]
# ## 1.3. 접촉정도

# %%
data_with_route['contact_number'].describe()
# Out:
# count    332.00
# mean      24.27
# std       95.07
# min        0.00
# 25%        2.00
# 50%        5.00
# 75%       17.25
# max     1160.00
# Name: contact_number, dtype: float64

# %%
plt.subplot(1,2,1)
data_with_route['contact_number'].plot(kind = 'hist')
plt.ylim(bottom=0)
plt.xlim(left=0)
plt.subplot(1,2,2)
sns.distplot(data_with_route['contact_number'])
plt.ylim(bottom=0)
plt.xlim(left=0)
plt.show()

# %%
data_with_route[data_with_route['contact_number'] == 1160]
# Out:
#      patient_id  global_num     sex  birth_year  age country province city  \
# 764  1200000031       31.00  female     1959.00  60s   Korea    Daegu  NaN
#
#     disease      infection_case  ...  infected_by  contact_number  \
# 764     NaN  Shincheonji Church  ...          nan         1160.00
#
#      symptom_onset_date confirmed_date released_date deceased_date     state  \
# 764                 NaN     2020-02-18           NaN           NaN  isolated
#
#     infection essential  non-essential
# 764     group     11.00           5.00
#
# [1 rows x 21 columns]

# %%
print('original data shape:', data_with_route.shape)
data_with_route = data_with_route[data_with_route['contact_number'].notna()]
print('data shape after removing missing values in contact_number:', data_with_route.shape)
# Out:
# original data shape: (1199, 21)
# data shape after removing missing values in contact_number: (332, 21)

# %%
data = data_with_route.copy()

# %% [markdown]
# ## 1.4. 확진받기까지 걸린 시간 (Diagnosis time)

# %%
print('data shape:', data.shape)
print('missing values in symptom_onset_date:', data[data['symptom_onset_date'].isna()].shape)
print('missing values in confirmed_date:', data[data['confirmed_date'].isna()].shape)
# Out:
# data shape: (332, 21)
# missing values in symptom_onset_date: (208, 21)
# missing values in confirmed_date: (0, 21)

# %%
### Cleaning symptom onset date
data[data['symptom_onset_date'] == ' ']
data['symptom_onset_date'] = np.where((data['symptom_onset_date'] == ' '), None, data['symptom_onset_date'])

### Remove missing values in symptom_onset_date
print('original data shape: ', data.shape)
data = data[data['symptom_onset_date'].notna()]
print('data excluding missing values in symptom_onset_date: ', data.shape)
# Out:
# original data shape:  (332, 21)
# data excluding missing values in symptom_onset_date:  (124, 21)

# %%
### Define time that lapsed between the onset of COVID-19 symptoms and the official COVID-19 diagnosis

## Convert str into date func.
def convert_date(x):
    x = pd.datetime.strptime(x, '%Y-%m-%d').date()
    return x

# %%
## convert symptom_onset_date/confirmed_date into date format
data['symptom_onset_date'] = data['symptom_onset_date'].apply(lambda x : convert_date(x))
data['confirmed_date'] = data['confirmed_date'].apply(lambda x: convert_date(x))

data.head(3)
# Out:
#     patient_id  global_num     sex  birth_year  age country province  \
# 0   1000000001        2.00    male     1964.00  50s   Korea    Seoul
# 3   1000000004        7.00    male     1991.00  20s   Korea    Seoul
# 13  1000000014       30.00  female     1952.00  60s   Korea    Seoul
#
#           city disease        infection_case  ...   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow  ...           nan
# 3      Mapo-gu     NaN       overseas inflow  ...           nan
# 13   Jongno-gu     NaN  contact with patient  ... 1000000013.00
#
#     contact_number  symptom_onset_date confirmed_date released_date  \
# 0            75.00          2020-01-22     2020-01-23    2020-02-05
# 3             9.00          2020-01-26     2020-01-30    2020-02-15
# 13           27.00          2020-02-06     2020-02-16    2020-03-12
#
#    deceased_date     state   infection essential  non-essential
# 0            NaN  released    overseas      1.00           1.00
# 3            NaN  released    overseas      1.00           0.00
# 13           NaN  released  individual     10.00           3.00
#
# [3 rows x 21 columns]

# %%
## find time lapsed between symptom_onset_date and confirmed_date
data['days_notice'] = data['confirmed_date'] - data['symptom_onset_date'] 
data['hours_notice'] = data['days_notice'].apply(lambda x: round(x.total_seconds()/3600, 2))
data['days'] = data['hours_notice'].apply(lambda x: int(x/24))
data.head(3)
# Out:
#     patient_id  global_num     sex  birth_year  age country province  \
# 0   1000000001        2.00    male     1964.00  50s   Korea    Seoul
# 3   1000000004        7.00    male     1991.00  20s   Korea    Seoul
# 13  1000000014       30.00  female     1952.00  60s   Korea    Seoul
#
#           city disease        infection_case  ...  confirmed_date  \
# 0   Gangseo-gu     NaN       overseas inflow  ...      2020-01-23
# 3      Mapo-gu     NaN       overseas inflow  ...      2020-01-30
# 13   Jongno-gu     NaN  contact with patient  ...      2020-02-16
#
#     released_date  deceased_date     state   infection essential  \
# 0      2020-02-05            NaN  released    overseas      1.00
# 3      2020-02-15            NaN  released    overseas      1.00
# 13     2020-03-12            NaN  released  individual     10.00
#
#    non-essential days_notice hours_notice  days
# 0           1.00      1 days        24.00     1
# 3           0.00      4 days        96.00     4
# 13          3.00     10 days       240.00    10
#
# [3 rows x 24 columns]

# %% [markdown]
# # 2. Building cluster model
# ## 2.1. Feature transformation

# %%
data_ = data[['patient_id', 
              'days', 
              'contact_number', 
              'essential', 'non-essential', 
              'infection']]
data_.reset_index(drop = True, inplace = True)
print(data_.shape)
data_.head()
# Out:
# (124, 6)
#    patient_id  days  contact_number  essential  non-essential   infection
# 0  1000000001     1           75.00       1.00           1.00    overseas
# 1  1000000004     4            9.00       1.00           0.00    overseas
# 2  1000000014    10           27.00      10.00           3.00  individual
# 3  1000000015     8            8.00       6.00           3.00       group
# 4  1000000302     1            8.00       1.00           0.00    overseas

# %% [markdown]
# ### 2.1.1. transformation of categorical variable

# %%
encoder = OneHotEncoder(categories = 'auto', sparse=False)
encoder.fit(np.array(data_['infection']).reshape(-1, 1))
inf_dummies = encoder.transform(np.array(data_['infection']).reshape(-1, 1))
dummies = pd.DataFrame(inf_dummies.astype(int), columns = ['infection_' + x for x in encoder.categories_[0]])
data_ = data_.join(dummies)
print(data_.shape)
data_.head()
# Out:
# (124, 10)
#    patient_id  days  contact_number  essential  non-essential   infection  \
# 0  1000000001     1           75.00       1.00           1.00    overseas
# 1  1000000004     4            9.00       1.00           0.00    overseas
# 2  1000000014    10           27.00      10.00           3.00  individual
# 3  1000000015     8            8.00       6.00           3.00       group
# 4  1000000302     1            8.00       1.00           0.00    overseas
#
#    infection_group  infection_individual  infection_overseas  \
# 0                0                     0                   1
# 1                0                     0                   1
# 2                0                     1                   0
# 3                1                     0                   0
# 4                0                     0                   1
#
#    infection_unknown
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %% [markdown]
# ### 2.1.2. scaling

# %%
inputs = ['days', 
          'essential', 'non-essential', 'contact_number',
          'infection_group', 'infection_individual', 'infection_overseas', 'infection_unknown']

X = data_[inputs]
print(X.shape)
X.head()
# Out:
# (124, 8)
#    days  essential  non-essential  contact_number  infection_group  \
# 0     1       1.00           1.00           75.00                0
# 1     4       1.00           0.00            9.00                0
# 2    10      10.00           3.00           27.00                0
# 3     8       6.00           3.00            8.00                1
# 4     1       1.00           0.00            8.00                0
#
#    infection_individual  infection_overseas  infection_unknown
# 0                     0                   1                  0
# 1                     0                   1                  0
# 2                     1                   0                  0
# 3                     0                   0                  0
# 4                     0                   1                  0

# %%
X[X['essential'].isnull()]
# Out:
# Empty DataFrame
# Columns: [days, essential, non-essential, contact_number, infection_group, infection_individual, infection_overseas, infection_unknown]
# Index: []

# %%
X = X.values
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X
# Out:
# array([[-0.59312961, -0.94094357, -0.65823438,  1.27664853, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [-0.10605629, -0.94094357, -0.89143742, -0.18625984, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [ 0.86809036,  2.43556134, -0.1918283 ,  0.21271517, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.54337481,  0.93489249, -0.1918283 , -0.20842512,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.59312961, -0.94094357, -0.89143742, -0.20842512, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [ 0.21865926,  0.18455806,  0.50778081, -0.36358207, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [-0.59312961, -0.94094357, -0.42503134, -0.03110289, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.59312961, -0.94094357, -0.89143742, -0.36358207,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.26841406, -0.19060915,  0.27457777,  0.10188878, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.10605629,  1.68522691, -0.65823438,  0.03539294,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.59312961, -0.19060915,  0.27457777, -0.34141679,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.75548739, -0.19060915, -0.89143742, -0.18625984, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.59312961, -0.56577636, -0.42503134, -0.20842512, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.59312961,  0.18455806,  0.50778081,  0.0797235 ,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.59312961, -0.94094357, -0.65823438,  0.16838461,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.26841406,  0.93489249, -0.1918283 , -0.2305904 , -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.43077184, -0.94094357, -0.89143742, -0.34141679,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.21865926,  2.06039412, -0.42503134, -0.14192928, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [ 0.21865926,  1.68522691,  1.20738992,  0.27921101, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.43077184, -0.94094357,  1.20738992,  0.52302907, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.26841406,  1.3100597 , -0.89143742,  0.21271517, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.10605629,  1.3100597 , -0.42503134, -0.14192928, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.05630149,  1.68522691, -0.1918283 ,  1.18798742, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.59312961, -0.94094357, -0.89143742, -0.31925151, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.59312961, -0.94094357, -0.89143742, -0.31925151,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.75548739,  0.18455806, -0.65823438, -0.36358207, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.21865926,  0.18455806,  0.50778081, -0.27492095, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [ 0.38101704,  3.93623019,  4.00582637, -0.38574734, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.75548739, -0.56577636, -0.89143742, -0.36358207, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [ 0.05630149, -0.19060915,  1.90699903, -0.36358207, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.43077184,  0.18455806,  2.60660814,  0.45653323, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [ 0.21865926, -0.56577636,  0.04137473, -0.31925151,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.54337481,  2.81072855,  2.60660814, -0.09759873, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.26841406, -0.19060915, -0.89143742, -0.38574734,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.43077184,  1.3100597 , -0.65823438, -0.36358207, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.10605629, -0.94094357, -0.89143742, -0.34141679, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.05630149, -0.56577636, -0.89143742, -0.31925151, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.05630149, -0.56577636, -0.65823438, -0.27492095,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.26841406, -0.56577636, -0.89143742, -0.36358207, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.21865926,  2.06039412, -0.89143742, -0.05326817, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [ 0.21865926,  0.18455806, -0.89143742, -0.27492095, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.26841406, -0.56577636, -0.89143742, -0.38574734,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 1.19280591,  1.68522691, -0.65823438, -0.29708623, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.59312961,  0.18455806,  0.04137473, -0.29708623, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [-0.43077184, -0.56577636, -0.89143742, -0.34141679, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.86809036, -0.19060915,  1.90699903,  0.14621934, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 3.62817254, -0.56577636, -0.1918283 ,  0.14621934, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.59312961, -0.56577636, -0.65823438, -0.25275567, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.10605629, -0.56577636, -0.89143742, -0.14192928, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.59312961, -0.19060915, -0.89143742, -0.38574734, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.54337481, -0.19060915, -0.89143742, -0.36358207, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.10605629, -0.94094357,  0.50778081, -0.18625984, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [-0.59312961,  0.18455806, -0.42503134, -0.27492095, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [-0.43077184, -0.56577636,  0.04137473,  0.14621934, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [-0.59312961, -0.56577636, -0.89143742, -0.38574734, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.21865926, -0.56577636,  0.97418688, -0.20842512, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [-0.10605629, -0.94094357,  0.04137473, -0.31925151, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [-0.26841406, -0.56577636, -0.1918283 , -0.34141679, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [-0.59312961, -0.19060915, -0.89143742, -0.36358207, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [-0.59312961, -0.56577636,  0.27457777, -0.36358207, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [ 0.38101704,  0.18455806, -0.65823438, -0.34141679, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [ 0.86809036,  0.93489249,  0.50778081,  2.78388746, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [ 0.38101704,  1.3100597 , -0.65823438,  9.5886279 , -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [ 0.21865926,  0.18455806,  0.50778081,  0.27921101, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [ 0.38101704, -0.94094357, -0.89143742, -0.14192928, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [ 0.05630149, -1.31611078, -0.1918283 , -0.34141679,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 5.90118139, -1.31611078, -0.65823438, -0.25275567,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.38101704, -1.31611078, -0.1918283 , -0.27492095,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.05630149, -0.94094357,  0.50778081,  0.10188878,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.21865926, -0.94094357, -0.42503134,  0.12405406,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.59312961, -0.94094357, -0.89143742, -0.31925151,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.05630149, -0.94094357,  0.27457777, -0.18625984,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.59312961, -0.94094357, -0.89143742, -0.05326817, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.59312961, -0.56577636, -0.89143742, -0.34141679, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.26841406,  0.55972528,  0.50778081,  0.10188878, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.59312961,  0.18455806,  1.20738992,  0.3900374 ,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.59312961, -0.19060915, -0.42503134, -0.29708623,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.59312961, -0.19060915,  1.20738992, -0.25275567, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.26841406, -0.56577636, -0.1918283 , -0.18625984,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.10605629,  0.18455806, -0.1918283 ,  0.52302907, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.10605629,  0.18455806,  0.74098384,  0.74468185, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.21865926,  1.3100597 ,  2.60660814,  2.49573884,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.26841406, -0.94094357, -0.65823438, -0.31925151,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.05630149, -0.19060915,  0.04137473,  0.30137628,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.26841406, -0.56577636, -0.1918283 , -0.27492095,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.05630149,  2.06039412,  4.2390294 , -0.16409456,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.59312961,  0.93489249,  0.74098384, -0.05326817,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 7.03768581,  0.93489249,  0.04137473,  0.74468185, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.26841406,  0.55972528, -0.42503134, -0.34141679,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.38101704,  0.18455806,  0.27457777, -0.36358207, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.21865926, -0.94094357,  0.50778081, -0.27492095,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.21865926, -0.56577636,  0.50778081, -0.31925151,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.59312961,  0.93489249,  2.37340511,  0.14621934,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.21865926, -0.19060915,  1.44059296, -0.14192928,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.21865926,  0.18455806,  0.97418688, -0.34141679,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.59312961, -0.56577636, -0.65823438,  0.78901241,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.26841406, -0.56577636,  0.97418688, -0.34141679,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.26841406,  0.18455806,  0.27457777, -0.25275567,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.05630149,  0.18455806,  0.97418688, -0.27492095, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.05630149,  0.55972528, -0.42503134,  0.12405406, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.59312961,  1.68522691,  0.50778081, -0.20842512, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.59312961,  0.93489249,  1.20738992, -0.2305904 ,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [ 0.05630149,  0.93489249, -0.1918283 ,  1.96377216,  1.47630863,
#         -0.76794765, -0.38490018, -0.47720307],
#        [-0.59312961,  0.93489249,  1.20738992, -0.27492095, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.59312961,  0.18455806,  0.97418688, -0.16409456, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.26841406, -0.56577636, -0.65823438, -0.34141679, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.43077184, -0.94094357, -0.89143742, -0.36358207, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.10605629,  0.93489249,  0.27457777, -0.27492095, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [ 0.05630149,  0.18455806,  0.74098384, -0.2305904 , -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.43077184,  1.3100597 , -0.42503134, -0.38574734, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.10605629, -0.56577636, -0.65823438, -0.16409456, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.38101704,  2.43556134, -0.89143742, -0.27492095, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.26841406, -0.94094357, -0.89143742, -0.38574734, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.05630149,  0.18455806, -0.65823438, -0.31925151, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.59312961, -0.94094357, -0.89143742, -0.29708623, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.38101704, -0.94094357, -0.89143742, -0.29708623, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.75548739, -0.56577636, -0.65823438, -0.38574734, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [ 0.54337481,  0.55972528,  0.50778081, -0.14192928, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.59312961, -0.56577636,  0.50778081, -0.29708623, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.43077184, -0.94094357,  0.04137473, -0.29708623, -0.67736514,
#          1.3021721 , -0.38490018, -0.47720307],
#        [-0.59312961, -0.56577636,  0.27457777, -0.29708623, -0.67736514,
#         -0.76794765,  2.59807621, -0.47720307],
#        [ 1.19280591, -1.31611078, -0.65823438, -0.36358207, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [ 1.19280591, -0.94094357, -0.89143742, -0.34141679, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393],
#        [-0.10605629, -0.94094357, -0.1918283 , -0.34141679, -0.67736514,
#         -0.76794765, -0.38490018,  2.09554393]])

# %% [markdown]
# ## 2.2. Dimensionality reduction using PCA

# %%
pca = PCA(n_components = 2)
principalComponents = pca.fit_transform(X)
principalDF = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2'])

ax = sns.scatterplot(x='PC1', y='PC2', data = principalDF) 
sns.regplot(x=principalDF['PC1'], y=principalDF['PC2'], fit_reg=False)

display()

# %% [markdown]
# ## 2.3. Clustering

# %%
cluster_range = range(1,7)
cluster_errors = []
for n in cluster_range:
    cluster = KMeans(n)
    cluster.fit(X)
    cluster_errors.append(cluster.inertia_)

plt.figure(figsize = (6,6))
plt.plot(cluster_range, cluster_errors)
plt.title('the Elbow method')
plt.xlabel('the number of clusters')
plt.ylabel('within-cluster sum of squares')
display()

# %%
km = KMeans(n_clusters = 5)
km.fit(X)

centroids = km.cluster_centers_ 
labels= km.labels_
data_['label'] = labels

# %%
pca = PCA(n_components = 2)
principalComponents = pca.fit_transform(X)
principalDF = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2'])

plt.figure(figsize = (8,8))
plt.scatter('PC1', 'PC2', data = principalDF, c = labels)

display()

# %%
data_.groupby(['label'])['patient_id'].count()
# Out:
# label
# 0    15
# 1    39
# 2    45
# 3    24
# 4     1
# Name: patient_id, dtype: int64

# %%
data_[data_['label'] == 1]
# Out:
#      patient_id  days  contact_number  essential  non-essential infection  \
# 3    1000000015     8            8.00       6.00           3.00     group
# 7    1100000017     1            1.00       1.00           0.00     group
# 9    1100000022     4           19.00       8.00           1.00     group
# 10   1100000024     1            2.00       3.00           5.00     group
# 13   1100000030     1           21.00       4.00           6.00     group
# 14   1100000034     1           25.00       1.00           1.00     group
# 16   1100000049     2            2.00       1.00           0.00     group
# 24   1100000064     1            3.00       1.00           0.00     group
# 31   1100000076     6            3.00       2.00           4.00     group
# 33   1100000080     3            0.00       3.00           0.00     group
# 37   1100000084     5            5.00       2.00           1.00     group
# 41   1100000089     3            0.00       2.00           0.00     group
# 65   1700000020     5            2.00       0.00           3.00     group
# 66   1700000028    41            6.00       0.00           1.00     group
# 67   1700000031     7            5.00       0.00           3.00     group
# 68   1700000033     5           22.00       1.00           6.00     group
# 69   1700000036     6           23.00       1.00           2.00     group
# 70   1700000037     1            3.00       1.00           0.00     group
# 71   1700000038     5            9.00       1.00           5.00     group
# 75   4100000002     1           35.00       4.00           9.00     group
# 76   4100000003     1            4.00       3.00           2.00     group
# 78   4100000005     3            9.00       2.00           3.00     group
# 81   4100000008     6          130.00       7.00          15.00     group
# 82   4100000009     3            3.00       1.00           1.00     group
# 83   4100000011     5           31.00       3.00           4.00     group
# 84   4100000012     3            5.00       2.00           3.00     group
# 85   4100000013     5           10.00       9.00          22.00     group
# 86   4100000017     1           15.00       6.00           7.00     group
# 88   4100000019     3            2.00       5.00           2.00     group
# 90   4100000022     6            5.00       1.00           6.00     group
# 91   4100000023     6            3.00       2.00           6.00     group
# 92   4100000024     1           24.00       6.00          14.00     group
# 93   4100000026     6           11.00       3.00          10.00     group
# 94   4100000027     6            2.00       4.00           8.00     group
# 95   4100000028     1           53.00       2.00           1.00     group
# 96   4100000029     3            2.00       2.00           8.00     group
# 97   4100000032     3            6.00       4.00           5.00     group
# 101  4100000037     1            7.00       6.00           9.00     group
# 102  4100000039     5          106.00       6.00           3.00     group
#
#      infection_group  infection_individual  infection_overseas  \
# 3                  1                     0                   0
# 7                  1                     0                   0
# 9                  1                     0                   0
# 10                 1                     0                   0
# 13                 1                     0                   0
# 14                 1                     0                   0
# 16                 1                     0                   0
# 24                 1                     0                   0
# 31                 1                     0                   0
# 33                 1                     0                   0
# 37                 1                     0                   0
# 41                 1                     0                   0
# 65                 1                     0                   0
# 66                 1                     0                   0
# 67                 1                     0                   0
# 68                 1                     0                   0
# 69                 1                     0                   0
# 70                 1                     0                   0
# 71                 1                     0                   0
# 75                 1                     0                   0
# 76                 1                     0                   0
# 78                 1                     0                   0
# 81                 1                     0                   0
# 82                 1                     0                   0
# 83                 1                     0                   0
# 84                 1                     0                   0
# 85                 1                     0                   0
# 86                 1                     0                   0
# 88                 1                     0                   0
# 90                 1                     0                   0
# 91                 1                     0                   0
# 92                 1                     0                   0
# 93                 1                     0                   0
# 94                 1                     0                   0
# 95                 1                     0                   0
# 96                 1                     0                   0
# 97                 1                     0                   0
# 101                1                     0                   0
# 102                1                     0                   0
#
#      infection_unknown  label
# 3                    0      1
# 7                    0      1
# 9                    0      1
# 10                   0      1
# 13                   0      1
# 14                   0      1
# 16                   0      1
# 24                   0      1
# 31                   0      1
# 33                   0      1
# 37                   0      1
# 41                   0      1
# 65                   0      1
# 66                   0      1
# 67                   0      1
# 68                   0      1
# 69                   0      1
# 70                   0      1
# 71                   0      1
# 75                   0      1
# 76                   0      1
# 78                   0      1
# 81                   0      1
# 82                   0      1
# 83                   0      1
# 84                   0      1
# 85                   0      1
# 86                   0      1
# 88                   0      1
# 90                   0      1
# 91                   0      1
# 92                   0      1
# 93                   0      1
# 94                   0      1
# 95                   0      1
# 96                   0      1
# 97                   0      1
# 101                  0      1
# 102                  0      1

# %%
data_ = data_[data_['patient_id'] != 1300000001]
data_.reset_index(drop = True, inplace = True)

X = data_[inputs]
print('X shape:', X.shape) 

X = X.values
scaler = StandardScaler()
X = scaler.fit_transform(X)

km = KMeans(n_clusters = 4)
km.fit(X)

centroids = km.cluster_centers_ 
labels= km.labels_
data_['label'] = labels
# Out:
# X shape: (123, 8)

# %%
pca = PCA(n_components = 2)
principalComponents = pca.fit_transform(X)
principalDF = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2'])

plt.figure(figsize = (8,8))
plt.scatter('PC1', 'PC2', data = principalDF, c = labels)

display()

# %% [markdown]
# Cluter 분석 결과, 행동 패턴으로 구분되는 확진자들의 유형 네 가지 가 파악되었습니다.
# 1. 첫번째 유형(Hypermobile & hypersocial unknowns): 감염 경로가 알려지지 않은 확진자들
# 2. 두번째 유형(Moderate groupies): 집단 감염
# 3. 세번째 유형(Social minimalists): 개인적으로 감염
# 4. 네번째 유형(Overseas non-essentialists): 해외 유입
